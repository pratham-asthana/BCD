# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
data_40X = "Combined_Dataset\\40X_BALANCED"
data_100X = "Combined_Dataset\\100X_BALANCED"
data_200X = "Combined_Dataset\\200X_BALANCED"
data_400X = "Combined_Dataset\\400X_BALANCED"

# %%
classes = ['Benign', 'Malignant']

# %% [markdown]
# # 40X

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_40X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 2025, 'Malignant': 2070}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 40X Dataset')
plt.show()

# %% [markdown]
# # 100X

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_100X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 2044, 'Malignant': 2137}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 100X Dataset')
plt.show()

# %% [markdown]
# # 200X

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_200X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 2023, 'Malignant': 2090}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 200X Dataset')
plt.show()

# %% [markdown]
# # 400X

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_400X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 1988, 'Malignant': 1932}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 400X Dataset')
plt.show()
