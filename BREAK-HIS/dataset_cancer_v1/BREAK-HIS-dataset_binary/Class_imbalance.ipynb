# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
data_40X = "40X"
data_100X = "100X"
data_200X = "200X"
data_400X = "400X"

# %%
classes = ['Benign', 'Malignant']

# %% [markdown]
# # 40X DATA

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_40X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 625, 'Malignant': 1370}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 40X Dataset')
plt.show()

# %% [markdown]
# # 100X DATA

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_100X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 644, 'Malignant': 1437}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 100X Dataset')
plt.show()

# %% [markdown]
# # 200X DATA

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_200X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 623, 'Malignant': 1390}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 200X Dataset')
plt.show()

# %% [markdown]
# # 400X DATA

# %%
class_counts = {}
for cls in classes:
    folder_path = os.path.join(data_400X, cls)
    files = os.listdir(folder_path)

    images = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

print("Class count:", class_counts)
# Out:
# Class count: {'Benign': 588, 'Malignant': 1232}

# %%
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'red'])
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution in 400X Dataset')
plt.show()
